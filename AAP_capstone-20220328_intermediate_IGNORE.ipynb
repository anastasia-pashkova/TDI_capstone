# %%
import seaborn as sns
sns.set()

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.dates as mdates

# %%
df = pd.read_csv('contributions-github-20220202-124509_full.csv', parse_dates=['date'], low_memory=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94170 entries, 0 to 94169
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   username  94170 non-null  object
#  1   count     94170 non-null  int64
#  2   date      94170 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 2.2+ MB

# %%
df.shape
# Out:
# (94170, 3)

# %%
df.dtypes
# Out:
# username            object
# count                int64
# date        datetime64[ns]
# dtype: object

# %%
df.head(20)
# Out:
#    username  count       date
# 0    aashah      0 2021-01-01
# 1    aashah      0 2021-01-02
# 2    aashah      0 2021-01-03
# 3    aashah      0 2021-01-04
# 4    aashah      7 2021-01-05
# 5    aashah     11 2021-01-06
# 6    aashah      5 2021-01-07
# 7    aashah      8 2021-01-08
# 8    aashah      0 2021-01-09
# 9    aashah      0 2021-01-10
# 10   aashah      3 2021-01-11
# 11   aashah      5 2021-01-12
# 12   aashah     12 2021-01-13
# 13   aashah     21 2021-01-14
# 14   aashah     20 2021-01-15
# 15   aashah      0 2021-01-16
# 16   aashah      0 2021-01-17
# 17   aashah      0 2021-01-18
# 18   aashah      5 2021-01-19
# 19   aashah      6 2021-01-20

# %%
df_user1 = df.loc[df['username'] == 'domofactor']

# %%
df_user1_weekly = df_user1.resample('W-MON', on='date').sum()

# %%
df_user1_weekly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 53 entries, 2021-01-04 to 2022-01-03
# Freq: W-MON
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   count   53 non-null     int64
# dtypes: int64(1)
# memory usage: 848.0 bytes

# %%
df_user1_weekly.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df_user1_monthly = df_user1.resample('M', on='date').sum()

# %%
df_user1_monthly.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
sns.barplot(df_user1_weekly.index, df_user1_weekly['count'])
# Out:
# /opt/conda/envs/data3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='date', ylabel='count'>

# %%
#sns.barplot(x = "survived", y = "class", data = titanic_dataset)

# %%
user1_barplot_weekly = sns.barplot(x =df_user1_weekly.index, y = "count", data = df_user1_weekly, color='b')
plt.xticks(rotation=90)

user1_barplot_weekly.xaxis.set_major_locator(mdates.DayLocator(interval=4))
# user1_barplot_weekly.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d')) 

plt.show()

# %%
user1_barplot_monthly = sns.barplot(x =df_user1_monthly.index, y = "count", data = df_user1_monthly, color='b')
plt.xticks(rotation=90)

# user1_barplot_weekly.xaxis.set_major_locator(mdates.DayLocator(interval=1))
# user1_barplot_weekly.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d')) 

plt.show()

# %%
user1_barplot_monthly = sns.barplot(x =df_user1_monthly.index, y = "count", data = df_user1_monthly, color='b')
plt.xticks(rotation=90)

# user1_barplot_weekly.xaxis.set_major_locator(mdates.DayLocator(interval=1))
# user1_barplot_weekly.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d')) 

plt.show()

# %%
# example

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

x = [0,5,9,10,15]
y = [0,1,2,3,4]
fig, ax = plt.subplots()
ax.plot(x,y)
start, end = ax.get_xlim()
ax.xaxis.set_ticks(np.arange(start, end, 2))
ax.xaxis.set_major_formatter(ticker.FormatStrFormatter('%0.1f'))
plt.show()

# %%
df_user1_weekly.plot.bar()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df_user1_monthly.plot.bar()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df_user2 = df.loc[df['username'] == 'dctucker']

# %%
df_user2.head(20)
# Out:
#        username  count       date
# 92710  dctucker      0 2021-01-01
# 92711  dctucker      0 2021-01-02
# 92712  dctucker      0 2021-01-03
# 92713  dctucker      0 2021-01-04
# 92714  dctucker      0 2021-01-05
# 92715  dctucker      0 2021-01-06
# 92716  dctucker      0 2021-01-07
# 92717  dctucker      0 2021-01-08
# 92718  dctucker      3 2021-01-09
# 92719  dctucker      2 2021-01-10
# 92720  dctucker      2 2021-01-11
# 92721  dctucker      3 2021-01-12
# 92722  dctucker      1 2021-01-13
# 92723  dctucker      1 2021-01-14
# 92724  dctucker      1 2021-01-15
# 92725  dctucker      2 2021-01-16
# 92726  dctucker      1 2021-01-17
# 92727  dctucker      2 2021-01-18
# 92728  dctucker      3 2021-01-19
# 92729  dctucker      1 2021-01-20

# %%
df_user2_weekly = df_user2.resample('W-MON', on='date').sum()

# %%
df_user2_weekly.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df_user2_monthly = df_user2.resample('M', on='date').sum()

# %%
df_user2_monthly.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94170 entries, 0 to 94169
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   username  94170 non-null  object
#  1   count     94170 non-null  int64
#  2   date      94170 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 2.2+ MB

# %%
# df_grouped_date = df.groupby([df['date'].dt.date], as_index=False).sum()

# %%
df_grouped_date = df.groupby('date', as_index=False).sum()

# %%
df_grouped_date.head(20)
# Out:
#          date  count
# 0  2021-01-01    386
# 1  2021-01-02    527
# 2  2021-01-03    376
# 3  2021-01-04   1239
# 4  2021-01-05   1242
# 5  2021-01-06    979
# 6  2021-01-07   1194
# 7  2021-01-08    950
# 8  2021-01-09    410
# 9  2021-01-10    266
# 10 2021-01-11   1801
# 11 2021-01-12   1745
# 12 2021-01-13   1372
# 13 2021-01-14   1556
# 14 2021-01-15   1240
# 15 2021-01-16    427
# 16 2021-01-17    284
# 17 2021-01-18    883
# 18 2021-01-19   8832
# 19 2021-01-20   1476

# %%
df_grouped_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    365 non-null    datetime64[ns]
#  1   count   365 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 5.8 KB

# %%
df_grouped_date_weekly = df_grouped_date.resample('W-MON', on='date').sum()

# %%
# the entire company

# %%
all_barplot_weekly = sns.barplot(x =df_grouped_date_weekly.index, y = "count", data = df_grouped_date_weekly, color='b')
plt.xticks(rotation=90)

all_barplot_weekly.xaxis.set_major_locator(mdates.DayLocator(interval=4))
# user1_barplot_weekly.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d')) 

plt.show()

# %%
# all users monthly

# %%
df_grouped_date_monthly = df_grouped_date.resample('M', on='date').sum()

# %%
all_barplot_monthly = sns.barplot(x =df_grouped_date_monthly.index, y = "count", data = df_grouped_date_monthly, color='b')
plt.xticks(rotation=90)

# user1_barplot_weekly.xaxis.set_major_locator(mdates.DayLocator(interval=1))
# user1_barplot_weekly.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d')) 

plt.show()

# %%
# all GitHub members Monthly

all_barplot_monthly = sns.barplot(x =df_grouped_date_monthly.index, y = "count", data = df_grouped_date_monthly, color='b')
plt.xticks(rotation=90)

plt.show()
